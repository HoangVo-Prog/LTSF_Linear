# %%
# !git clone https://github.com/HoangVo-Prog/LTSF_Linear.git
# Out:
# fatal: destination path 'LTSF_Linear' already exists and is not an empty directory.

# %%
# !python LTSF_Linear/elastic_net/v1/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/LTSF_Linear/elastic_net/v1/main.py", line 210, in <module>
#     main()
#   File "/content/LTSF_Linear/elastic_net/v1/main.py", line 29, in main
#     data_path = find_data_path("FPT_train.csv")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LTSF_Linear/elastic_net/v1/data_utils.py", line 31, in find_data_path
#     raise FileNotFoundError(f"Cannot find {filename} in known locations")
# FileNotFoundError: Cannot find FPT_train.csv in known locations
