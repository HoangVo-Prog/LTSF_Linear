# %%
# !git clone https://github.com/HoangVo-Prog/LTSF_Linear.git
# Out:
# fatal: destination path 'LTSF_Linear' already exists and is not an empty directory.

# %%
# !python LTSF_Linear/elastic_net/v1/main.py
# Out:
# Raw data: (1149, 7) 2020-08-03 00:00:00 -> 2025-03-10 00:00:00
# Number of samples used to fit scaler: 587
#
# Grid search 1 - chọn window_size, window_type, alpha, l1_ratio cơ bản:
# Best config (coarse search): {'window_size': 126, 'window_type': 'expanding', 'alpha': 0.005, 'l1_ratio': 0.5}
#    window_size window_type  alpha  l1_ratio  n_val      mse       mae
# 0          126   expanding  0.005       0.5    541  0.00019  0.009989
# 1          126   expanding  0.005       0.8    541  0.00019  0.009989
# 2          126   expanding  0.010       0.5    541  0.00019  0.009989
# 3          126   expanding  0.010       0.8    541  0.00019  0.009989
# 4          252   expanding  0.005       0.5    541  0.00019  0.009989
# 5          252   expanding  0.005       0.8    541  0.00019  0.009989
# 6          252   expanding  0.010       0.5    541  0.00019  0.009989
# 7          252   expanding  0.010       0.8    541  0.00019  0.009989
# ...
